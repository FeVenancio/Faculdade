# %%
print("hello world");
# Out:
# hello world

# %%
1+1
# Out:
# 2

# %%
"ronney" + "lira"
# Out:
# 'ronneylira'

# %%
x = 4 + 6
print(x);
# Out:
# 10

# %%
print("argumento 1", "argumento 2", "argumento 3");
# Out:
# argumento 1 argumento 2 argumento 3

# %%
print("a", "b", "c", sep = " + ");
# Out:
# a + b + c

# %%
print("facens", end = "");
print("estatisticas");
# Out:
# facensestatisticas

# %%
'''print("Estatisticas", )'''
# Out:
# 'print("Estatisticas", )'

# %%
# YOUR <CODE HERE>
# Maria - 999999 - Estatisticas - 2026
print("Felipe", 251670, "Estatisticas", 2026, sep = " - ");
# Out:
# Felipe - 251670 - Estatisticas - 2026

# %%
print(type(10.0));
print(type("Jesus"));
print(type(19));
# Out:
# <class 'float'>
# <class 'str'>
# <class 'int'>

# %%
pi = 3.14159;
print(pi);
# Out:
# 3.14159

# %%
a = b = c = 3;
print(a, b, c);
# Out:
# 3 3 3

# %%
a, b, c = 1, 2, 3;
print(a, b, c);
# Out:
# 1 2 3

# %%
c1 = 1;
C1 = "1";
print(type(c1));
print(type(C1));
# Out:
# <class 'int'>
# <class 'str'>

# %%
verdadeiro = True;
falso = False;
print(type(verdadeiro), type(falso), sep = " - ");
# Out:
# <class 'bool'> - <class 'bool'>

# %%
print(2 ** 2);
print(2 ** 10);
# Out:
# 4
# 1024

# %%
print(11 % 2); # módulo da divisão
# Out:
# 1

# %%
print(10 // 3.4); # só divide a parte inteira
# Out:
# 2.0

# %%
print("ABC" * 3);
# Out:
# ABCABCABC

# %%
print("a" == "a" and "a" < "b");
# Out:
# True

# %%
print("a" > "b" or "c" > "a");
# Out:
# False

# %%
a = 10;
if (a % 2) == 1:
  print("número impar");
else:
  print("númumero par");
print("fim do programa");
# Out:
# númumero par
# final do programa
